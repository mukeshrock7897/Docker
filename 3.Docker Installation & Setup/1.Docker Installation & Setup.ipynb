# %% [markdown]
# ---
#
# ## 📦 **2. Docker Installation & Setup**
#
# ---
#
# ### ✅ **Installing Docker on Windows / macOS / Linux**
#
# **Option 1: Docker Desktop (Recommended for Beginners)**
#
# * All-in-one UI + CLI package for Windows/macOS
# * Includes Docker Engine, CLI, Docker Compose
#
# 🔗 [Install Docker Desktop →](https://www.docker.com/products/docker-desktop/)
#
# **Option 2: CLI-only (for Linux Servers/Cloud VMs)**
# Use the following commands:
#
# ```bash
# # Ubuntu / Debian
# sudo apt update
# sudo apt install docker.io
# sudo systemctl start docker
# sudo systemctl enable docker
# ```
#
# ✅ Add your user to the docker group:
#
# ```bash
# sudo usermod -aG docker $USER
# ```
#
# ---
#
# ### 🖥️ **Docker Desktop vs Docker CLI**
#
# | Feature  | Docker Desktop            | Docker CLI (Only)        |
# | -------- | ------------------------- | ------------------------ |
# | OS       | Windows / macOS           | Linux (primarily)        |
# | GUI      | ✅ Yes                     | ❌ No                     |
# | Best For | Dev machines, learners    | Servers, CI/CD pipelines |
# | Extras   | Comes with Docker Compose | Must install separately  |
#
# ---
#
# ### 🔍 **Verifying Installation**
#
# After installation:
#
# ```bash
# docker --version        # Check Docker CLI version
# docker info             # Detailed system info
# docker run hello-world  # Test container
# ```
#
# Expected output:
# `Hello from Docker!` – confirms Docker is working ✅
#
# ---
#
# ### 🔐 **Docker Hub Sign-Up & Login**
#
# **Why?**
#
# * Pull public images
# * Push your own images to share or deploy
#
# 🔗 [Sign up → Docker Hub](https://hub.docker.com/)
#
# Login via CLI:
#
# ```bash
# docker login
# # Enter your Docker Hub username & password
# ```
#
# ---
